# %%
from Graph import Graph

graph = Graph()
graph.add_company("Company A", "TICKER_A")
graph.add_company("Company B", "TICKER_B")
graph.add_risk_factor("Market Volatility")
graph.visualize_graph(1)
